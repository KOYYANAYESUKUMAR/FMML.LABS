# %% [markdown]
# <a href="https://colab.research.google.com/github/KOYYANAYESUKUMAR/FMML.LABS/blob/main/FMML_M8L3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2025-03-15 23:03:58--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.109.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   223MB/s    in 0.3s
#
# 2025-03-15 23:03:59 (223 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 2489    1310.6288v1  Current studies about motor imagery based reha...  stat
# 936     1406.1231v1  Although artificial neural networks have occas...  stat
# 23063  1803.03432v1  We propose practical extensions to Bayesian op...  stat
# 11055   1312.5734v1  We propose SPARFA-Trace, a new machine learnin...  stat
# 31017  1802.01273v1  Train Pilot is a very tedious and stressful jo...    cs
# ...             ...                                                ...   ...
# 3883    1412.4659v3  Is it possible to find the sparsest vector (di...    cs
# 6447   1702.02530v1  This paper proposes a generic classification s...  stat
# 11273  1506.08910v1  Single Index Models (SIMs) are simple yet flex...  stat
# 14597  cs/0404025v1  This paper describes the Patent Retrieval Task...    cs
# 22245  1510.02354v1  We consider sequential decision making problem...  stat
#
#                                                    title  year  \
# 2489   Spatial-Spectral Boosting Analysis for Stroke ...  2013
# 936      Multi-task Neural Networks for QSAR Predictions  2014
# 23063         Bayesian Optimization for Dynamic Problems  2018
# 11055  Time-varying Learning and Content Analytics vi...  2013
# 31017  Face recognition for monitoring operator shift...  2018
# ...                                                  ...   ...
# 3883   Finding a sparse vector in a subspace: Linear ...  2014
# 6447   Learning detectors of malicious web requests f...  2017
# 11273    Learning Single Index Models in High Dimensions  2015
# 14597  Test Collections for Patent-to-Patent Retrieva...  2004
# 22245  The Knowledge Gradient with Logistic Belief Mo...  2015
#
#                                                 keywords
# 2489   [rehabilitation, appropriate, considerable, cl...
# 936    [artificial, occasionally, quantitative, struc...
# 23063  [practical, extensions, optimization, objectiv...
# 11055  [framework, analytics, education, applications...
# 31017  [stressful, countries, railroads, penalized, l...
# ...                                                  ...
# 3883   [considered, homogeneous, connections, diction...
# 6447   [classification, statistical, detectors, detec...
# 11273  [parametric, classification, regression, varia...
# 14597  [describes, retrieval, collections, invalidity...
# 22245  [sequential, classification, repeatedly, selec...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 2489     [rehabilitation, appropriate, considerable, cl...
# 936      [artificial, occasionally, quantitative, struc...
# 23063    [practical, extensions, optimization, objectiv...
# 11055    [framework, analytics, education, applications...
# 31017    [stressful, countries, railroads, penalized, l...
#                                ...
# 21532    [extracting, nonstationary, component, modulat...
# 11347    [technical, computational, complexity, minimiz...
# 26105    [introduce, materials, advantage, recognition,...
# 251      [algorithm, systematic, artificial, progressio...
# 887      [embedding, techniques, representation, dimens...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8638 words.
# Out of those 4558 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="28abed96-eac9-44fa-8fa4-e8ba83954afd" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("28abed96-eac9-44fa-8fa4-e8ba83954afd")) {                    Plotly.newPlot(                        "28abed96-eac9-44fa-8fa4-e8ba83954afd",                        [{"x":["effectiveness","stochastic","experiments","algorithm","configurations","mechanism","preconditions","variations","knowledge","parameters","simulation","plasticity","important","introduces","predetermined","potential","classification","mechanisms","detecting","collected","demonstrate","considerable","contribute","appropriate","heuristic","rehabilitation","overfitting","conducted","leveraging","structure","successful","literature","competition","occasionally","artificial","approaches","alternative","relationship","applications","quantitative","dominated","compounds","predictions","performance","techniques","activities","practical","functions","technique","information","objective","synthetic","extensions","spatiotemporal","temporally","determines","evaluations","instances","optimization","correlations","exploiting","available","forgetting","education","interacting","difficulties","associations","comparable","intrinsic","estimated","filtering","assessment","transitions","difficulty","organization","evolution","approximate","experimental","answering","quantities","analyzing","estimates","predicting","unobserved","personalized","analytics","responses","questions","resources","framework","collaborative","scheduled","allocated","railroads","monitoring","identified","recognize","automated","operating","increased","continuously","correctly","intervals","penalized","countries","recognition","acquisition","locomotive","approximation","application","observations","maximizing","factorization","computing","dictionaries","iteratively","characterized","coherence","particular","equiangular","established","guarantees","effective","properties","therefore","typically","denoising","approximating","depending","dictionary","separation","algorithms","likelihood","unsupervised","optimizing","assignments","presented","community","statistical","detectability","communities","demonstrated","selection","outperforms","detection","threshold","intelligently","constrained","significantly","supervised","generated","programming","theoretically","attributed","extensive","iteration","iterative","scalability","computational","convergence","undirected","guaranteed","different","implement","projected","projection","complexity","similarity","probabilistic","containing","databases","theoretical","potentials","measurement","burstiness","introduced","perspective","parameter","originates","scenarios","repeating","inaccurate","comprehensive","thousands","improvement","precision","additionally","variational","automatic","continual","generative","catastrophic","inference","successfully","discriminative","procedure","posterior","construct","constructing","terabytes"],"y":[219,132,612,784,28,103,1,90,350,252,72,2,342,79,0,161,476,39,83,73,532,36,27,78,55,1,23,78,42,325,92,130,22,1,118,471,94,69,410,75,6,1,99,900,394,32,123,211,258,705,157,131,41,12,16,11,56,86,264,31,93,282,14,6,20,34,11,84,32,61,70,39,15,45,12,56,103,366,57,9,61,61,100,4,17,22,28,75,71,555,32,4,5,2,31,46,45,86,34,46,19,32,20,7,11,396,47,2,127,222,82,18,37,135,16,38,24,18,266,0,51,69,261,225,132,96,36,18,28,52,28,584,75,137,64,13,186,80,150,1,16,110,139,266,336,28,11,52,271,178,170,109,41,12,172,40,84,39,289,111,13,38,754,72,9,50,237,154,161,63,61,156,19,44,2,138,72,120,8,97,4,9,61,26,140,66,75,48,205,0,130,8,212,84,92,111,45,82,43,0],"type":"bar"},{"x":["effectiveness","stochastic","experiments","algorithm","configurations","mechanism","preconditions" ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4558,), (4558, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8133333333333334

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Actual</span> <span style='background-color:rgba(0, 255, 0, 0.6666666666666666);'>causation</span> <span style=''>and</span> <span style=''>the</span> <span style=''>art</span> <span style=''>of</span> <span style=''>modeling</span> <br/><br/><span style=''>We</span> <span style=''>look</span> <span style=''>more</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>carefully</span> <span style=''>at</span> <span style=''>the</span> <span style=''>modeling</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>causality</span> <span style=''>using</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>structural</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>equations</span> <span style=''>It</span> <span style=''>is</span> <span style=''>clear</span> <span style=''>that</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>structural</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>equations</span> <span style=''>can</span> <span style=''>have</span> <span style=''>a</span> <span style=''>major</span> <span style=''>impact</span> <span style=''>on</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.4857142857142857);'>conclusions</span> <span style=''>we</span> <span style=''>draw</span> <span style=''>about</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>causality</span> <span style=''>In</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>particular</span> <span style=''>the</span> <span style=''>choice</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.31400966183574885);'>variables</span> <span style=''>and</span> <span style=''>their</span> <span style=''>values</span> <span style=''>can</span> <span style=''>also</span> <span style=''>have</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3244680851063829);'>significant</span> <span style=''>impact</span> <span style=''>on</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>causality</span> <span style=''>These</span> <span style=''>choices</span> <span style=''>are</span> <span style=''>to</span> <span style=''>some</span> <span style=''>extent</span> <span style='background-color:rgba(0, 255, 0, 0.8709677419354838);'>subjective</span> <span style=''>We</span> <span style=''>consider</span> <span style=''>what</span> <span style=''>counts</span> <span style=''>as</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>appropriate</span> <span style=''>choice</span> <span style=''>More</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generally</span> <span style=''>we</span> <span style=''>consider</span> <span style=''>what</span> <span style=''>makes</span> <span style=''>a</span> <span style=''>model</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>appropriate</span> <span style=''>model</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>especially</span> <span style=''>if</span> <span style=''>we</span> <span style=''>want</span> <span style=''>to</span> <span style=''>take</span> <span style=''>defaults</span> <span style=''>into</span> <span style=''>account</span> <span style=''>as</span> <span style=''>was</span> <span style=''>argued</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.34400000000000003);'>necessary</span> <span style=''>in</span> <span style=''>recent</span> <span style=''>work</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Overdispersed</span> <span style=''>Black</span> <span style=''>Box</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Variational</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Inference</span> <br/><br/><span style=''>We</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>introduce</span> <span style=''>overdispersed</span> <span style=''>black</span> <span style=''>box</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>variational</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inference</span> <span style=''>a</span> <span style=''>method</span> <span style=''>to</span> <span style=''>reduce</span> <span style=''>the</span> <span style=''>variance</span> <span style=''>of</span> <span style=''>the</span> <span style=''>Monte</span> <span style=''>Carlo</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimator</span> <span style=''>of</span> <span style=''>the</span> <span style=''>gradient</span> <span style=''>in</span> <span style=''>black</span> <span style=''>box</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>variational</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inference</span> <span style=''>Instead</span> <span style=''>of</span> <span style=''>taking</span> <span style=''>samples</span> <span style=''>from</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>variational</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distribution</span> <span style=''>we</span> <span style=''>use</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>importance</span> <span style=''>sampling</span> <span style=''>to</span> <span style=''>take</span> <span style=''>samples</span> <span style=''>from</span> <span style=''>an</span> <span style=''>overdispersed</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distribution</span> <span style=''>in</span> <span style=''>the</span> <span style=''>same</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>exponential</span> <span style=''>family</span> <span style=''>as</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>variational</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approximation</span> <span style=''>Our</span> <span style=''>approach</span> <span style=''>is</span> <span style=''>general</span> <span style=''>since</span> <span style=''>it</span> <span style=''>can</span> <span style=''>be</span> <span style=''>readily</span> <span style=''>applied</span> <span style=''>to</span> <span style=''>any</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>exponential</span> <span style=''>family</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distribution</span> <span style=''>which</span> <span style=''>is</span> <span style=''>the</span> <span style=''>typical</span> <span style=''>choice</span> <span style=''>for</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>variational</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approximation</span> <span style=''>We</span> <span style=''>run</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>experiments</span> <span style=''>on</span> <span style=''>two</span> <span style=''>non</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>conjugate</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>probabilistic</span> <span style=''>models</span> <span style=''>to</span> <span style=''>show</span> <span style=''>that</span> <span style=''>our</span> <span style=''>method</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>effectively</span> <span style=''>reduces</span> <span style=''>the</span> <span style=''>variance</span> <span style=''>and</span> <span style=''>the</span> <span style=''>overhead</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>introduced</span> <span style=''>by</span> <span style=''>the</s ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Linear</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Probability</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Forecasting</span> <br/><br/><span style=''>Multi</span> <span style=''>class</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>classification</span> <span style=''>is</span> <span style=''>one</span> <span style=''>of</span> <span style=''>the</span> <span style=''>most</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>important</span> <span style=''>tasks</span> <span style=''>in</span> <span style=''>machine</span> <span style=''>learning</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>consider</span> <span style=''>two</span> <span style=''>online</span> <span style=''>multi</span> <span style=''>class</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>classification</span> <span style=''>problems</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>classification</span> <span style=''>by</span> <span style=''>a</span> <span style=''>linear</span> <span style=''>model</span> <span style=''>and</span> <span style=''>by</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>kernelized</span> <span style=''>model</span> <span style=''>The</span> <span style=''>quality</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>predictions</span> <span style=''>is</span> <span style=''>measured</span> <span style=''>by</span> <span style=''>the</span> <span style=''>Brier</span> <span style=''>loss</span> <span style=''>function</span> <span style=''>We</span> <span style=''>suggest</span> <span style=''>two</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>computationally</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>efficient</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>to</span> <span style=''>work</span> <span style=''>with</span> <span style=''>these</span> <span style=''>problems</span> <span style=''>and</span> <span style=''>prove</span> <span style='background-color:rgba(255, 0, 0, 0.34453781512605036);'>theoretical</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>guarantees</span> <span style=''>on</span> <span style=''>their</span> <span style=''>losses</span> <span style=''>We</span> <span style=''>kernelize</span> <span style=''>one</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>and</span> <span style=''>prove</span> <span style='background-color:rgba(255, 0, 0, 0.34453781512605036);'>theoretical</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>guarantees</span> <span style=''>on</span> <span style=''>its</span> <span style=''>loss</span> <span style=''>We</span> <span style=''>perform</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>experiments</span> <span style=''>and</span> <span style=''>compare</span> <span style=''>our</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>with</span> <span style=''>logistic</span> <span style='background-color:rgba(255, 0, 0, 0.5185909980430529);'>regression</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Metric</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distances</span> <span style=''>derived</span> <span style=''>from</span> <span style=''>cosine</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>similarity</span> <span style=''>and</span> <span style=''>Pearson</span> <span style=''>and</span> <span style=''>Spearman</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>correlations</span> <br/><br/><span style=''>We</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>investigate</span> <span style=''>two</span> <span style=''>classes</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>transformations</span> <span style=''>of</span> <span style=''>cosine</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>similarity</span> <span style=''>and</span> <span style=''>Pearson</span> <span style=''>and</span> <span style=''>Spearman</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>correlations</span> <span style=''>into</span> <span style=''>metric</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distances</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>utilising</span> <span style=''>the</span> <span style=''>simple</span> <span style=''>tool</span> <span style=''>of</span> <span style=''>metric</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>preserving</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>functions</span> <span style=''>The</span> <span style=''>first</span> <span style=''>class</span> <span style=''>puts</span> <span style=''>anti</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>correlated</span> <span style=''>objects</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>maximally</span> <span style=''>far</span> <span style=''>apart</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Previously</span> <span style=''>known</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>transforms</span> <span style=''>fall</span> <span style=''>within</span> <span style=''>this</span> <span style=''>class</span> <span style=''>The</span> <span style=''>second</span> <span style=''>class</span> <span style=''>collates</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>correlated</span> <span style=''>and</span> <span style=''>anti</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>correlated</span> <span style=''>objects</span> <span style=''>An</span> <span style=''>example</span> <span style=''>of</span> <span style=''>such</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>transformation</span> <span style=''>that</span> <span style=''>yields</span> <span style=''>a</span> <span style=''>metric</span> <span style=''>distance</span> <span style=''>is</span> <span style=''>the</span> <span style=''>sine</span> <span style=''>function</span> <span style=''>when</span> <span style=''>applied</span> <span style=''>to</span> <span style=''>centered</span> <span style=''>data</span> <br/><br/>

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	automatic (0.07326661901358113)
# 	segmentation (0.06576125804145819)
# 	knowledge (0.12508934953538242)
# 	representation (0.1290207290922087)
# 	architecture (0.08970693352394568)
# 	information (0.25196568977841316)
# 	detection (0.12008577555396711)
# 	different (0.2694781987133667)
# 	convolutional (0.13259471050750535)
# 	recognition (0.14152966404574696)
#
# Some Statistics words are:
# 	stochastic (0.13486513486513488)
# 	statistical (0.14385614385614387)
# 	optimization (0.18681318681318682)
# 	estimation (0.17332667332667331)
# 	theoretical (0.15984015984015984)
# 	algorithm (0.3876123876123876)
# 	distribution (0.18831168831168832)
# 	inference (0.2087912087912088)
# 	dimensional (0.1888111888111888)
# 	regression (0.1938061938061938)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="4db6b175-798d-4efe-81e1-131e756daed9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4db6b175-798d-4efe-81e1-131e756daed9")) {                    Plotly.newPlot(                        "4db6b175-798d-4efe-81e1-131e756daed9",                        [{"x":["effectiveness","stochastic","experiments","algorithm","configurations","mechanism","preconditions","variations","knowledge","parameters","simulation","plasticity","important","introduces","predetermined","potential","classification","mechanisms","detecting","collected","demonstrate","considerable","contribute","appropriate","heuristic","rehabilitation","overfitting","conducted","leveraging","structure","successful","literature","competition","occasionally","artificial","approaches","alternative","relationship","applications","quantitative","dominated","compounds","predictions","performance","techniques","activities","practical","functions","technique","information","objective","synthetic","extensions","spatiotemporal","temporally","determines","evaluations","instances","optimization","correlations","exploiting","available","forgetting","education","interacting","difficulties","associations","comparable","intrinsic","estimated","filtering","assessment","transitions","difficulty","organization","evolution","approximate","experimental","answering","quantities","analyzing","estimates","predicting","unobserved","personalized","analytics","responses","questions","resources","framework","collaborative","scheduled","allocated","railroads","monitoring","identified","recognize","automated","operating","increased","continuously","correctly","intervals","penalized","countries","recognition","acquisition","locomotive","approximation","application","observations","maximizing","factorization","computing","dictionaries","iteratively","characterized","coherence","particular","equiangular","established","guarantees","effective","properties","therefore","typically","denoising","approximating","depending","dictionary","separation","algorithms","likelihood","unsupervised","optimizing","assignments","presented","community","statistical","detectability","communities","demonstrated","selection","outperforms","detection","threshold","intelligently","constrained","significantly","supervised","generated","programming","theoretically","attributed","extensive","iteration","iterative","scalability","computational","convergence","undirected","guaranteed","different","implement","projected","projection","complexity","similarity","probabilistic","containing","databases","theoretical","potentials","measurement","burstiness","introduced","perspective","parameter","originates","scenarios","repeating","inaccurate","comprehensive","thousands","improvement","precision","additionally","variational","automatic","continual","generative","catastrophic","inference","successfully","discriminative","procedure","posterior","construct","constructing","terabytes","uncertainty","distributions","measuring","procedures","efficiently","intensity","outperform","astronomical","themselves","ancillary","quantifying","supercomputer","telescope","constructed","scientific","referring","benefiting","comprehension","constructions","generates","expression","expressions","generation","triangulation","minimizers","accurately","underlying","numerical","implementation","adjustment","solutions","initialized","comparison","optimally","optimality","calibrated","derivatives","robustness","generalization","interests","expectation","classifiers","combination","flexibility","increasing","bernoulli","empirically","specifically","satisfactory","classifier","accelerate","extensively","maintaining","traditional","aggressive","unbounded","embed ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	predetermined
# 	equiangular
# 	continual
# 	terabytes
# 	telescope
# 	autoimmune
# 	scleroderma
# 	conjugacy
# 	biophysical
# 	staleness
# 	manageable
# 	penalization
# 	reconstructive
# 	confounders
# 	schizophrenia
# 	recasting
# 	sequentialized
# 	unavoidably
# 	privately
# 	exposition
# Some words which never appear in Statistics papers:
# 	allocated
# 	railroads
# 	locomotive
# 	burstiness
# 	originates
# 	comprehension
# 	analyzers
# 	judgments
# 	morphemes
# 	declarative
# 	pathological
# 	discontinuity
# 	chromosomes
# 	generations
# 	chromosome
# 	inheritance
# 	vocabularies
# 	obligation
# 	detachable
# 	argumentation

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.073329645337759e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7616666666666667
